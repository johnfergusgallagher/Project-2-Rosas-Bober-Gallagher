# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
target_url ="https://api.sportsdata.io/v3/nfl/odds/json/GameOddsByWeek/2019/5?key=c4392318ef1e43c2b9cbea6e54eb3684"

response5 = requests.get("https://api.sportsdata.io/v3/nfl/odds/json/GameOddsByWeek/2019/5?key=c4392318ef1e43c2b9cbea6e54eb3684").json()
response6 = requests.get("https://api.sportsdata.io/v3/nfl/odds/json/GameOddsByWeek/2019/6?key=c4392318ef1e43c2b9cbea6e54eb3684").json()
#response5

# %%
whole_week5 = []

Score_ID_List = []

# %%
response5
# Out:
# [{'ScoreId': 17046,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-03T00:00:00',
#   'DateTime': '2019-10-03T20:20:00',
#   'AwayTeamId': 32,
#   'HomeTeamId': 30,
#   'AwayTeamName': 'LAR',
#   'HomeTeamName': 'SEA',
#   'GlobalGameId': 17046,
#   'GlobalAwayTeamId': 32,
#   'GlobalHomeTeamId': 30,
#   'HomeTeamScore': 41,
#   'AwayTeamScore': 40,
#   'TotalScore': 81,
#   'HomeRotationNumber': 415,
#   'AwayRotationNumber': 413,
#   'PregameOdds': [{'GameOddId': 167669,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T20:22:59',
#     'Updated': '2019-10-03T20:24:09',
#     'HomeMoneyLine': -168,
#     'AwayMoneyLine': 151,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -143,
#     'OverUnder': 67.3,
#     'OverPayout': -139,
#     'UnderPayout': -151,
#     'SportsbookId': 1},
#    {'GameOddId': 167670,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T20:24:10',
#     'Updated': '2019-10-03T20:26:49',
#     'HomeMoneyLine': -178,
#     'AwayMoneyLine': 151,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 66.6,
#     'OverPayout': -144,
#     'UnderPayout': -158,
#     'SportsbookId': 5},
#    {'GameOddId': 167619,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:04',
#     'Updated': '2019-10-03T20:19:00',
#     'HomeMoneyLine': -166,
#     'AwayMoneyLine': 146,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 7},
#    {'GameOddId': 167562,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:23:34',
#     'Updated': '2019-10-03T20:19:00',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 148,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 68.0,
#     'OverPayout': 137,
#     'UnderPayout': -165,
#     'SportsbookId': 8},
#    {'GameOddId': 167621,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:06',
#     'Updated': '2019-10-03T20:19:01',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 140,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 9},
#    {'GameOddId': 167620,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:05',
#     'Updated': '2019-10-03T20:19:01',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 140,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 10},
#    {'GameOddId': 167623,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:07',
#     'Updated': '2019-10-03T20:19:02',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 140,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 12},
#    {'GameOddId': 167622,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:06',
#     'Updated': '2019-10-03T20:19:02',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 140,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 13},
#    {'GameOddId': 167624,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T19:55:07',
#     'Updated': '2019-10-03T20:19:03',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 140,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -165,
#     'UnderPayout': -141,
#     'SportsbookId': 14},
#    {'GameOddId': 167661,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T20:18:47',
#     'Updated': '2019-10-03T20:19:54',
#     'HomeMoneyLine': -170,
#     'AwayMoneyLine': 143,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 66.6,
#     'OverPayout': -163,
#     'UnderPayout': -144,
#     'SportsbookId': 22},
#    {'GameOddId': 167649,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17046,
#     'Created': '2019-10-03T20:14:27',
#     'Updated': '2019-10-03T20:19:54',
#     'HomeMoneyLine': -172,
#     'AwayMoneyLine': 144,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -2.1,
#     'AwayPointSpread': 2.8,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 66.6,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17047,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 1,
#   'HomeTeamId': 7,
#   'AwayTeamName': 'ARI',
#   'HomeTeamName': 'CIN',
#   'GlobalGameId': 17047,
#   'GlobalAwayTeamId': 1,
#   'GlobalHomeTeamId': 7,
#   'HomeTeamScore': 32,
#   'AwayTeamScore': 36,
#   'TotalScore': 67,
#   'HomeRotationNumber': 626,
#   'AwayRotationNumber': 625,
#   'PregameOdds': [{'GameOddId': 174078,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:02:40',
#     'HomeMoneyLine': -220,
#     'AwayMoneyLine': 198,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -139,
#     'OverUnder': 63.8,
#     'OverPayout': 139,
#     'UnderPayout': -155,
#     'SportsbookId': 1},
#    {'GameOddId': 174371,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T13:08:16',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': -217,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -154,
#     'OverUnder': 63.8,
#     'OverPayout': -146,
#     'UnderPayout': -155,
#     'SportsbookId': 5},
#    {'GameOddId': 172631,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:08:04',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': -222,
#     'AwayMoneyLine': 196,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 171742,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T09:40:18',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': -228,
#     'AwayMoneyLine': 198,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -158,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 8},
#    {'GameOddId': 172620,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:07:38',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -229,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 172619,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:07:37',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -229,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 172629,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:07:40',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -229,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 172621,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:07:39',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': -229,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 172630,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T11:07:41',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -229,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -168,
#     'AwayPointSpreadPayout': 140,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 168813,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-05T10:20:12',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -217,
#     'AwayMoneyLine': 181,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 65.2,
#     'OverPayout': -150,
#     'UnderPayout': -152,
#     'SportsbookId': 22},
#    {'GameOddId': 173915,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17047,
#     'Created': '2019-10-06T12:44:31',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': -220,
#     'AwayMoneyLine': 185,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17048,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 4,
#   'HomeTeamId': 34,
#   'AwayTeamName': 'BUF',
#   'HomeTeamName': 'TEN',
#   'GlobalGameId': 17048,
#   'GlobalAwayTeamId': 4,
#   'GlobalHomeTeamId': 34,
#   'HomeTeamScore': 13,
#   'AwayTeamScore': 19,
#   'TotalScore': 29,
#   'HomeRotationNumber': 645,
#   'AwayRotationNumber': 644,
#   'PregameOdds': [{'GameOddId': 174084,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:02:40',
#     'HomeMoneyLine': -251,
#     'AwayMoneyLine': 224,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -139,
#     'AwayPointSpreadPayout': -150,
#     'OverUnder': 54.2,
#     'OverPayout': -139,
#     'UnderPayout': -151,
#     'SportsbookId': 1},
#    {'GameOddId': 174377,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T13:08:17',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -140,
#     'AwayPointSpreadPayout': -162,
#     'OverUnder': 53.5,
#     'OverPayout': -147,
#     'UnderPayout': -155,
#     'SportsbookId': 5},
#    {'GameOddId': 171995,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:02:18',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': -240,
#     'AwayMoneyLine': 206,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 7},
#    {'GameOddId': 171798,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T09:43:22',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 214,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -172,
#     'AwayPointSpreadPayout': 144,
#     'OverUnder': 54.2,
#     'OverPayout': 137,
#     'UnderPayout': -165,
#     'SportsbookId': 8},
#    {'GameOddId': 171990,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:01:39',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 199,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 9},
#    {'GameOddId': 171993,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:01:44',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 199,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 10},
#    {'GameOddId': 171991,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:01:41',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 199,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 12},
#    {'GameOddId': 171994,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:01:45',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 199,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 13},
#    {'GameOddId': 171992,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T10:01:42',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -247,
#     'AwayMoneyLine': 199,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 54.2,
#     'OverPayout': -150,
#     'UnderPayout': -154,
#     'SportsbookId': 14},
#    {'GameOddId': 168840,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-05T10:52:32',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -210,
#     'AwayMoneyLine': 173,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -3.4,
#     'AwayPointSpread': 4.7,
#     'HomePointSpreadPayout': -158,
#     'AwayPointSpreadPayout': -146,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 173606,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17048,
#     'Created': '2019-10-06T12:30:56',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': -254,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -165,
#     'AwayPointSpreadPayout': 151,
#     'OverUnder': 53.5,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17049,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 6,
#   'HomeTeamId': 25,
#   'AwayTeamName': 'CHI',
#   'HomeTeamName': 'OAK',
#   'GlobalGameId': 17049,
#   'GlobalAwayTeamId': 6,
#   'GlobalHomeTeamId': 25,
#   'HomeTeamScore': 33,
#   'AwayTeamScore': 29,
#   'TotalScore': 62,
#   'HomeRotationNumber': 623,
#   'AwayRotationNumber': 622,
#   'PregameOdds': [{'GameOddId': 174086,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:04:20',
#     'HomeMoneyLine': 332,
#     'AwayMoneyLine': -383,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 12.3,
#     'AwayPointSpread': -8.9,
#     'HomePointSpreadPayout': -143,
#     'AwayPointSpreadPayout': -146,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -139,
#     'SportsbookId': 1},
#    {'GameOddId': 174428,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T13:13:23',
#     'Updated': '2019-10-06T13:23:21',
#     'HomeMoneyLine': 357,
#     'AwayMoneyLine': -439,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 13.2,
#     'AwayPointSpread': -9.6,
#     'HomePointSpreadPayout': -169,
#     'AwayPointSpreadPayout': 141,
#     'OverUnder': 54.9,
#     'OverPayout': -144,
#     'UnderPayout': -158,
#     'SportsbookId': 5},
#    {'GameOddId': 173262,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:03',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': 330,
#     'AwayMoneyLine': -382,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 12.3,
#     'AwayPointSpread': -8.9,
#     'HomePointSpreadPayout': -157,
#     'AwayPointSpreadPayout': -146,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 173291,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:06:10',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': 323,
#     'AwayMoneyLine': -384,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 12.3,
#     'AwayPointSpread': -8.9,
#     'HomePointSpreadPayout': 137,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 54.2,
#     'OverPayout': -158,
#     'UnderPayout': -144,
#     'SportsbookId': 8},
#    {'GameOddId': 173273,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:07',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 316,
#     'AwayMoneyLine': -405,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 11.3,
#     'AwayPointSpread': -8.2,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 173272,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:06',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 316,
#     'AwayMoneyLine': -405,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 11.3,
#     'AwayPointSpread': -8.2,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 173275,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:08',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 316,
#     'AwayMoneyLine': -405,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 11.3,
#     'AwayPointSpread': -8.2,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 173274,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:08',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': 316,
#     'AwayMoneyLine': -405,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 11.3,
#     'AwayPointSpread': -8.2,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 173276,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:04:09',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 316,
#     'AwayMoneyLine': -405,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 11.3,
#     'AwayPointSpread': -8.2,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 54.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 168634,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-04T20:00:43',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -320,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 55.6,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 174077,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17049,
#     'Created': '2019-10-06T12:56:20',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': 330,
#     'AwayMoneyLine': -426,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 12.3,
#     'AwayPointSpread': -8.9,
#     'HomePointSpreadPayout': 137,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 54.9,
#     'OverPayout': -144,
#     'UnderPayout': -158,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17050,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 33,
#   'HomeTeamId': 22,
#   'AwayTeamName': 'TB',
#   'HomeTeamName': 'NO',
#   'GlobalGameId': 17050,
#   'GlobalAwayTeamId': 33,
#   'GlobalHomeTeamId': 22,
#   'HomeTeamScore': 43,
#   'AwayTeamScore': 33,
#   'TotalScore': 76,
#   'HomeRotationNumber': 640,
#   'AwayRotationNumber': 638,
#   'PregameOdds': [{'GameOddId': 174083,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:02:40',
#     'HomeMoneyLine': -213,
#     'AwayMoneyLine': 191,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': 137,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.2,
#     'OverPayout': -146,
#     'UnderPayout': -144,
#     'SportsbookId': 1},
#    {'GameOddId': 174245,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T13:01:24',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': -213,
#     'AwayMoneyLine': 185,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -140,
#     'UnderPayout': -163,
#     'SportsbookId': 5},
#    {'GameOddId': 173090,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:54:01',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': -216,
#     'AwayMoneyLine': 189,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 173467,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T12:22:10',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': -214,
#     'AwayMoneyLine': 187,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -144,
#     'UnderPayout': -158,
#     'SportsbookId': 8},
#    {'GameOddId': 173082,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:53:47',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -227,
#     'AwayMoneyLine': 183,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 173080,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:53:47',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -227,
#     'AwayMoneyLine': 183,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 173086,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:53:49',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -227,
#     'AwayMoneyLine': 183,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 173084,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:53:48',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': -227,
#     'AwayMoneyLine': 183,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 173088,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:53:50',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -227,
#     'AwayMoneyLine': 183,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 168794,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-05T09:57:29',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -231,
#     'AwayMoneyLine': 191,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 172789,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17050,
#     'Created': '2019-10-06T11:22:26',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': -220,
#     'AwayMoneyLine': 185,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17051,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 20,
#   'HomeTeamId': 23,
#   'AwayTeamName': 'MIN',
#   'HomeTeamName': 'NYG',
#   'GlobalGameId': 17051,
#   'GlobalAwayTeamId': 20,
#   'GlobalHomeTeamId': 23,
#   'HomeTeamScore': 14,
#   'AwayTeamScore': 38,
#   'TotalScore': 52,
#   'HomeRotationNumber': 632,
#   'AwayRotationNumber': 630,
#   'PregameOdds': [{'GameOddId': 174082,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:02:29',
#     'HomeMoneyLine': 283,
#     'AwayMoneyLine': -323,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 10.4,
#     'AwayPointSpread': -7.6,
#     'HomePointSpreadPayout': 139,
#     'AwayPointSpreadPayout': -154,
#     'OverUnder': 60.4,
#     'OverPayout': -146,
#     'UnderPayout': -144,
#     'SportsbookId': 1},
#    {'GameOddId': 174422,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T13:11:33',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': 273,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 10.4,
#     'AwayPointSpread': -7.6,
#     'HomePointSpreadPayout': -152,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.7,
#     'OverPayout': -154,
#     'UnderPayout': -148,
#     'SportsbookId': 5},
#    {'GameOddId': 174140,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:42',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': 268,
#     'AwayMoneyLine': -316,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 172518,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T11:00:50',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': 275,
#     'AwayMoneyLine': -323,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 10.4,
#     'AwayPointSpread': -7.6,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 8},
#    {'GameOddId': 174136,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:38',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 174135,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:37',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 174138,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:39',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 174137,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:38',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 174139,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:57:40',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 261,
#     'AwayMoneyLine': -330,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -148,
#     'AwayPointSpreadPayout': -155,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 168808,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-05T10:06:42',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': 250,
#     'AwayMoneyLine': -305,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 9.4,
#     'AwayPointSpread': -6.9,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 173976,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17051,
#     'Created': '2019-10-06T12:46:42',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': 275,
#     'AwayMoneyLine': -350,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 10.4,
#     'AwayPointSpread': -7.6,
#     'HomePointSpreadPayout': 137,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17052,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 24,
#   'HomeTeamId': 26,
#   'AwayTeamName': 'NYJ',
#   'HomeTeamName': 'PHI',
#   'GlobalGameId': 17052,
#   'GlobalAwayTeamId': 24,
#   'GlobalHomeTeamId': 26,
#   'HomeTeamScore': 43,
#   'AwayTeamScore': 11,
#   'TotalScore': 51,
#   'HomeRotationNumber': 637,
#   'AwayRotationNumber': 636,
#   'PregameOdds': [{'GameOddId': 174087,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:56:23',
#     'Updated': '2019-10-06T13:02:40',
#     'HomeMoneyLine': -1067,
#     'AwayMoneyLine': 802,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -139,
#     'AwayPointSpreadPayout': -150,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -139,
#     'SportsbookId': 1},
#    {'GameOddId': 174424,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T13:11:33',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': -1304,
#     'AwayMoneyLine': 877,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 5},
#    {'GameOddId': 173657,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:33',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': -1146,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 7},
#    {'GameOddId': 173366,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:12:23',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': -1030,
#     'AwayMoneyLine': 783,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 58.4,
#     'OverPayout': -158,
#     'UnderPayout': -144,
#     'SportsbookId': 8},
#    {'GameOddId': 173633,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:12',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -1373,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 9},
#    {'GameOddId': 173630,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:11',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': -1373,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 10},
#    {'GameOddId': 173639,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:14',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -1373,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 12},
#    {'GameOddId': 173636,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:13',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': -1373,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 13},
#    {'GameOddId': 173642,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:33:15',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': -1373,
#     'AwayMoneyLine': 892,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -150,
#     'SportsbookId': 14},
#    {'GameOddId': 168795,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-05T09:57:29',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -1214,
#     'AwayMoneyLine': 795,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.9,
#     'AwayPointSpread': 19.9,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 173604,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17052,
#     'Created': '2019-10-06T12:30:56',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': -1167,
#     'AwayMoneyLine': 810,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -19.2,
#     'AwayPointSpread': 19.2,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 59.0,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17053,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 3,
#   'HomeTeamId': 28,
#   'AwayTeamName': 'BAL',
#   'HomeTeamName': 'PIT',
#   'GlobalGameId': 17053,
#   'GlobalAwayTeamId': 3,
#   'GlobalHomeTeamId': 28,
#   'HomeTeamScore': 32,
#   'AwayTeamScore': 36,
#   'TotalScore': 67,
#   'HomeRotationNumber': 621,
#   'AwayRotationNumber': 619,
#   'PregameOdds': [{'GameOddId': 174085,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:03:16',
#     'HomeMoneyLine': 213,
#     'AwayMoneyLine': -238,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 6.6,
#     'AwayPointSpread': -4.8,
#     'HomePointSpreadPayout': -161,
#     'AwayPointSpreadPayout': 147,
#     'OverUnder': 60.4,
#     'OverPayout': -150,
#     'UnderPayout': -140,
#     'SportsbookId': 1},
#    {'GameOddId': 174419,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T13:11:33',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': 213,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': 144,
#     'AwayPointSpreadPayout': -172,
#     'OverUnder': 60.4,
#     'OverPayout': -158,
#     'UnderPayout': -144,
#     'SportsbookId': 5},
#    {'GameOddId': 172604,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:06:55',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': 206,
#     'AwayMoneyLine': -240,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 173433,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T12:18:03',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': 206,
#     'AwayMoneyLine': -239,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 6.6,
#     'AwayPointSpread': -4.8,
#     'HomePointSpreadPayout': -165,
#     'AwayPointSpreadPayout': 137,
#     'OverUnder': 61.1,
#     'OverPayout': -144,
#     'UnderPayout': -158,
#     'SportsbookId': 8},
#    {'GameOddId': 172575,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:05:53',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 199,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 172574,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:05:52',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 199,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 172577,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:05:54',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 199,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 172576,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:05:53',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': 199,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 172578,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:05:55',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 199,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 168757,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-05T08:56:22',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': 207,
#     'AwayMoneyLine': -251,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 172793,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17053,
#     'Created': '2019-10-06T11:24:35',
#     'Updated': '2019-10-06T12:59:44',
#     'HomeMoneyLine': 206,
#     'AwayMoneyLine': -247,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 5.7,
#     'AwayPointSpread': -4.1,
#     'HomePointSpreadPayout': 151,
#     'AwayPointSpreadPayout': -165,
#     'OverUnder': 60.4,
#     'OverPayout': -158,
#     'UnderPayout': -144,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17054,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T13:00:00',
#   'AwayTeamId': 21,
#   'HomeTeamId': 35,
#   'AwayTeamName': 'NE',
#   'HomeTeamName': 'WAS',
#   'GlobalGameId': 17054,
#   'GlobalAwayTeamId': 21,
#   'GlobalHomeTeamId': 35,
#   'HomeTeamScore': 13,
#   'AwayTeamScore': 45,
#   'TotalScore': 55,
#   'HomeRotationNumber': 634,
#   'AwayRotationNumber': 633,
#   'PregameOdds': [{'GameOddId': 174079,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:56:22',
#     'Updated': '2019-10-06T13:02:29',
#     'HomeMoneyLine': 928,
#     'AwayMoneyLine': -1278,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 21.3,
#     'AwayPointSpread': -21.3,
#     'HomePointSpreadPayout': -137,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -146,
#     'UnderPayout': -144,
#     'SportsbookId': 1},
#    {'GameOddId': 174423,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T13:11:33',
#     'Updated': '2019-10-06T13:13:13',
#     'HomeMoneyLine': 982,
#     'AwayMoneyLine': -1523,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 57.7,
#     'OverPayout': -152,
#     'UnderPayout': -150,
#     'SportsbookId': 5},
#    {'GameOddId': 173999,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:49:11',
#     'Updated': '2019-10-06T12:59:59',
#     'HomeMoneyLine': 1030,
#     'AwayMoneyLine': -1373,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 173434,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:18:03',
#     'Updated': '2019-10-06T12:59:34',
#     'HomeMoneyLine': 906,
#     'AwayMoneyLine': -1236,
#     'DrawMoneyLine': None,
#     'HomePointSpread': 22.7,
#     'AwayPointSpread': -22.7,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 58.4,
#     'OverPayout': 137,
#     'UnderPayout': -165,
#     'SportsbookId': 8},
#    {'GameOddId': 174002,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:49:14',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 961,
#     'AwayMoneyLine': -1531,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 174000,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:49:13',
#     'Updated': '2019-10-06T12:59:36',
#     'HomeMoneyLine': 961,
#     'AwayMoneyLine': -1531,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 174006,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:49:16',
#     'Updated': '2019-10-06T12:59:38',
#     'HomeMoneyLine': 961,
#     'AwayMoneyLine': -1531,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 174004,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17054,
#     'Created': '2019-10-06T12:49:15',
#     'Updated': '2019-10-06T12:59:37',
#     'HomeMoneyLine': 961,
#     'AwayMoneyLine': -1531,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': 22.0,
#     'AwayPointSpread': -22.0,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 57.7,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
# ...
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:16:15',
#     'Updated': '2019-10-06T16:24:32',
#     'HomeMoneyLine': -243,
#     'AwayMoneyLine': 217,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': 141,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 63.8,
#     'OverPayout': -147,
#     'UnderPayout': -143,
#     'SportsbookId': 1},
#    {'GameOddId': 174925,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:41:24',
#     'Updated': '2019-10-06T16:41:24',
#     'HomeMoneyLine': -254,
#     'AwayMoneyLine': 220,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.1,
#     'AwayPointSpread': 5.7,
#     'HomePointSpreadPayout': -176,
#     'AwayPointSpreadPayout': 147,
#     'OverUnder': 63.8,
#     'OverPayout': -158,
#     'UnderPayout': -146,
#     'SportsbookId': 5},
#    {'GameOddId': 174837,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:14:14',
#     'Updated': '2019-10-06T16:24:33',
#     'HomeMoneyLine': -250,
#     'AwayMoneyLine': 220,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 7},
#    {'GameOddId': 174869,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:21:59',
#     'Updated': '2019-10-06T16:24:34',
#     'HomeMoneyLine': -239,
#     'AwayMoneyLine': 206,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -165,
#     'UnderPayout': 137,
#     'SportsbookId': 8},
#    {'GameOddId': 174830,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:13:39',
#     'Updated': '2019-10-06T16:24:36',
#     'HomeMoneyLine': -261,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 9},
#    {'GameOddId': 174835,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:14:02',
#     'Updated': '2019-10-06T16:24:35',
#     'HomeMoneyLine': -261,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 10},
#    {'GameOddId': 174832,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:13:41',
#     'Updated': '2019-10-06T16:24:38',
#     'HomeMoneyLine': -261,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 12},
#    {'GameOddId': 174831,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:13:40',
#     'Updated': '2019-10-06T16:24:37',
#     'HomeMoneyLine': -261,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 13},
#    {'GameOddId': 174833,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:13:41',
#     'Updated': '2019-10-06T16:24:38',
#     'HomeMoneyLine': -261,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -146,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 63.8,
#     'OverPayout': -157,
#     'UnderPayout': -147,
#     'SportsbookId': 14},
#    {'GameOddId': 168751,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-05T08:46:38',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -246,
#     'AwayMoneyLine': 205,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': -147,
#     'AwayPointSpreadPayout': -157,
#     'OverUnder': 64.5,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 174883,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17058,
#     'Created': '2019-10-06T16:24:15',
#     'Updated': '2019-10-06T16:24:55',
#     'HomeMoneyLine': -254,
#     'AwayMoneyLine': 213,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -4.8,
#     'AwayPointSpread': 6.6,
#     'HomePointSpreadPayout': 137,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 63.8,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17059,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-06T00:00:00',
#   'DateTime': '2019-10-06T20:20:00',
#   'AwayTeamId': 14,
#   'HomeTeamId': 16,
#   'AwayTeamName': 'IND',
#   'HomeTeamName': 'KC',
#   'GlobalGameId': 17059,
#   'GlobalAwayTeamId': 14,
#   'GlobalHomeTeamId': 16,
#   'HomeTeamScore': 18,
#   'AwayTeamScore': 26,
#   'TotalScore': 44,
#   'HomeRotationNumber': 654,
#   'AwayRotationNumber': 652,
#   'PregameOdds': [{'GameOddId': 175682,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T20:16:28',
#     'Updated': '2019-10-06T20:19:49',
#     'HomeMoneyLine': -688,
#     'AwayMoneyLine': 555,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -141,
#     'AwayPointSpreadPayout': -147,
#     'OverUnder': 76.2,
#     'OverPayout': 139,
#     'UnderPayout': -154,
#     'SportsbookId': 1},
#    {'GameOddId': 175779,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T20:28:12',
#     'Updated': '2019-10-06T20:35:31',
#     'HomeMoneyLine': -824,
#     'AwayMoneyLine': 614,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 75.5,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 5},
#    {'GameOddId': 175233,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:51',
#     'Updated': '2019-10-06T20:19:50',
#     'HomeMoneyLine': -810,
#     'AwayMoneyLine': 632,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 7},
#    {'GameOddId': 172635,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T11:08:41',
#     'Updated': '2019-10-06T20:19:51',
#     'HomeMoneyLine': -686,
#     'AwayMoneyLine': 549,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -158,
#     'OverUnder': 76.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 8},
#    {'GameOddId': 175228,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:04',
#     'Updated': '2019-10-06T20:19:53',
#     'HomeMoneyLine': -858,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 9},
#    {'GameOddId': 175227,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:02',
#     'Updated': '2019-10-06T20:19:52',
#     'HomeMoneyLine': -858,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 10},
#    {'GameOddId': 175230,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:06',
#     'Updated': '2019-10-06T20:19:55',
#     'HomeMoneyLine': -858,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 12},
#    {'GameOddId': 175229,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:05',
#     'Updated': '2019-10-06T20:19:54',
#     'HomeMoneyLine': -858,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 13},
#    {'GameOddId': 175231,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T18:52:07',
#     'Updated': '2019-10-06T20:19:56',
#     'HomeMoneyLine': -858,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -143,
#     'UnderPayout': -162,
#     'SportsbookId': 14},
#    {'GameOddId': 168664,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-04T21:36:51',
#     'Updated': '2019-10-05T11:03:02',
#     'HomeMoneyLine': -792,
#     'AwayMoneyLine': 584,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -15.1,
#     'AwayPointSpread': 15.1,
#     'HomePointSpreadPayout': -150,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 76.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 175456,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17059,
#     'Created': '2019-10-06T19:50:20',
#     'Updated': '2019-10-06T20:19:36',
#     'HomeMoneyLine': -824,
#     'AwayMoneyLine': 604,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -14.4,
#     'AwayPointSpread': 14.4,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 76.2,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []},
#  {'ScoreId': 17060,
#   'Season': 2019,
#   'SeasonType': 1,
#   'Week': 5,
#   'Day': '2019-10-07T00:00:00',
#   'DateTime': '2019-10-07T20:15:00',
#   'AwayTeamId': 8,
#   'HomeTeamId': 31,
#   'AwayTeamName': 'CLE',
#   'HomeTeamName': 'SF',
#   'GlobalGameId': 17060,
#   'GlobalAwayTeamId': 8,
#   'GlobalHomeTeamId': 31,
#   'HomeTeamScore': 43,
#   'AwayTeamScore': 6,
#   'TotalScore': 47,
#   'HomeRotationNumber': 656,
#   'AwayRotationNumber': 655,
#   'PregameOdds': [{'GameOddId': 182689,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T20:06:19',
#     'Updated': '2019-10-07T20:14:59',
#     'HomeMoneyLine': -303,
#     'AwayMoneyLine': 268,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.9,
#     'AwayPointSpread': 9.4,
#     'HomePointSpreadPayout': -147,
#     'AwayPointSpreadPayout': -141,
#     'OverUnder': 65.2,
#     'OverPayout': -150,
#     'UnderPayout': -140,
#     'SportsbookId': 1},
#    {'GameOddId': 182864,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T20:29:58',
#     'Updated': '2019-10-07T20:35:36',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 264,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.9,
#     'AwayPointSpread': 9.4,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -158,
#     'UnderPayout': -144,
#     'SportsbookId': 5},
#    {'GameOddId': 182301,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:47:11',
#     'Updated': '2019-10-07T20:14:56',
#     'HomeMoneyLine': -302,
#     'AwayMoneyLine': 258,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 7},
#    {'GameOddId': 182382,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T19:05:46',
#     'Updated': '2019-10-07T20:14:57',
#     'HomeMoneyLine': -302,
#     'AwayMoneyLine': 258,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -158,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 65.2,
#     'OverPayout': -165,
#     'UnderPayout': 137,
#     'SportsbookId': 8},
#    {'GameOddId': 182306,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:47:16',
#     'Updated': '2019-10-07T20:14:59',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 254,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 9},
#    {'GameOddId': 182304,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:47:15',
#     'Updated': '2019-10-07T20:14:59',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 254,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 10},
#    {'GameOddId': 182297,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:46:45',
#     'Updated': '2019-10-07T20:14:58',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 254,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 12},
#    {'GameOddId': 182308,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:47:18',
#     'Updated': '2019-10-07T20:14:57',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 254,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 13},
#    {'GameOddId': 182299,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T18:46:46',
#     'Updated': '2019-10-07T20:14:59',
#     'HomeMoneyLine': -316,
#     'AwayMoneyLine': 254,
#     'DrawMoneyLine': 0,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 14},
#    {'GameOddId': 182732,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T20:12:24',
#     'Updated': '2019-10-07T20:14:56',
#     'HomeMoneyLine': -312,
#     'AwayMoneyLine': 257,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.2,
#     'AwayPointSpread': 8.5,
#     'HomePointSpreadPayout': -151,
#     'AwayPointSpreadPayout': -151,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 22},
#    {'GameOddId': 182659,
#     'Sportsbook': 'Scrambled',
#     'ScoreId': 17060,
#     'Created': '2019-10-07T20:02:13',
#     'Updated': '2019-10-07T20:14:55',
#     'HomeMoneyLine': -309,
#     'AwayMoneyLine': 247,
#     'DrawMoneyLine': None,
#     'HomePointSpread': -6.9,
#     'AwayPointSpread': 9.4,
#     'HomePointSpreadPayout': -144,
#     'AwayPointSpreadPayout': -144,
#     'OverUnder': 65.9,
#     'OverPayout': -151,
#     'UnderPayout': -151,
#     'SportsbookId': 23}],
#   'LiveOdds': []}]

# %%
#pp.pprint(whole_week5[0])
for Score_Data in response5:
    print(Score_Data["ScoreId"])
    print(Score_Data["PregameOdds"][0]["HomePointSpreadPayout"])
# Out:
# 17046
# -146
# 17047
# -150
# 17048
# -139
# 17049
# -143
# 17050
# 137
# 17051
# 139
# 17052
# -139
# 17053
# -161
# 17054
# -137
# 17055
# -174
# 17056
# -150
# 17057
# -154
# 17058
# 141
# 17059
# -141
# 17060
# -147

# %%
for Score_Data in response5:
    print(Score_Data["AwayTeamName"])

print(len(Score_Data["AwayTeamName"]))
# Out:
# LAR
# ARI
# BUF
# CHI
# TB
# MIN
# NYJ
# BAL
# NE
# JAX
# ATL
# DEN
# GB
# IND
# CLE
# 3

# %%
Score_Id = []
Week = []
Away_Team_Name = []
Home_Team_Name = []
Home_Team_Score = []
Away_Team_Score = []
Total_Score = []
Home_Money_Line = []
Away_Money_Line = []
Home_Point_Spread = []
Away_Point_Spread = []
Home_Point_Spread_Payout = []
Away_Point_Spread_Payout = []

# %%
for Score_Data in response5:
    Week.append(Score_Data["Week"])
    Away_Team_Name.append(Score_Data["AwayTeamName"])
    Home_Team_Name.append(Score_Data["HomeTeamName"])
    Home_Team_Score.append(Score_Data["HomeTeamScore"])
    Away_Team_Score.append(Score_Data["AwayTeamScore"])
    Total_Score.append(Score_Data["TotalScore"])
    Home_Money_Line.append(Score_Data["PregameOdds"][0]["HomeMoneyLine"])
    Away_Money_Line.append(Score_Data["PregameOdds"][0]["AwayMoneyLine"])
    Home_Point_Spread.append(Score_Data["PregameOdds"][0]["HomePointSpread"])
    Away_Point_Spread.append(Score_Data["PregameOdds"][0]["AwayPointSpread"])
    Home_Point_Spread_Payout.append(Score_Data["PregameOdds"][0]["HomePointSpreadPayout"])
    Away_Point_Spread_Payout.append(Score_Data["PregameOdds"][0]["AwayPointSpreadPayout"])

# %%
print(
len(Away_Team_Name),
len(Home_Team_Name),
len(Home_Team_Score),
len(Away_Team_Score),
len(Total_Score),
len(Home_Money_Line),
len(Away_Money_Line),
len(Home_Point_Spread),
len(Away_Point_Spread),
len(Home_Point_Spread_Payout),
len(Away_Point_Spread_Payout)
)
# Out:
# 15 15 15 15 15 15 15 15 15 15 15

# %%
len(Home_Point_Spread_Payout)
# Out:
# 15

# %%
Betting_df = pd.DataFrame({

"Away_Team_Name": Away_Team_Name,
"Home_Team_Name": Home_Team_Name,
"Home_Team_Score": Home_Team_Score,
"Away_Team_Score": Away_Team_Score,
"Total_Score": Total_Score,
"Home_Money_Line": Home_Money_Line,
"Away_Money_Line": Away_Money_Line,
"Home_Point_Spread": Home_Point_Spread,
"Away_Point_Spread": Away_Point_Spread,
"Home_Point_Spread_Payout": Home_Point_Spread_Payout,
"Away_Point_Spread_Payout": Away_Point_Spread_Payout,
})

# %%
Betting_df
# Out:
#    Away_Team_Name Home_Team_Name  Home_Team_Score  Away_Team_Score  \
# 0             LAR            SEA               41               40
# 1             ARI            CIN               32               36
# 2             BUF            TEN               13               19
# 3             CHI            OAK               33               29
# 4              TB             NO               43               33
# 5             MIN            NYG               14               38
# 6             NYJ            PHI               43               11
# 7             BAL            PIT               32               36
# 8              NE            WAS               13               45
# 9             JAX            CAR               47               37
# 10            ATL            HOU               73               44
# 11            DEN            LAC               18               27
# 12             GB            DAL               33               47
# 13            IND             KC               18               26
# 14            CLE             SF               43                6
#
#     Total_Score  Home_Money_Line  Away_Money_Line  Home_Point_Spread  \
# 0            81             -168              151               -2.1
# 1            67             -220              198               -4.1
# 2            29             -251              224               -4.8
# 3            62              332             -383               12.3
# 4            76             -213              191               -4.1
# 5            52              283             -323               10.4
# 6            51            -1067              802              -19.2
# 7            67              213             -238                6.6
# 8            55              928            -1278               21.3
# 9            84             -253              227               -4.1
# 10          117             -284              253               -5.5
# 11           45             -308              272               -5.5
# 12           80             -243              217               -4.8
# 13           44             -688              555              -14.4
# 14           47             -303              268               -6.9
#
#     Away_Point_Spread  Home_Point_Spread_Payout  Away_Point_Spread_Payout
# 0                 2.8                      -146                      -143
# 1                 5.7                      -150                      -139
# 2                 6.6                      -139                      -150
# 3                -8.9                      -143                      -146
# 4                 5.7                       137                      -151
# 5                -7.6                       139                      -154
# 6                19.2                      -139                      -150
# 7                -4.8                      -161                       147
# 8               -21.3                      -137                      -151
# 9                 5.7                      -174                       158
# 10                7.5                      -150                      -139
# 11                7.5                      -154                       140
# 12                6.6                       141                      -157
# 13               14.4                      -141                      -147
# 14                9.4                      -147                      -141
